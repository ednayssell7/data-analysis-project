# %%
#import data
import pandas as pd
import numpy as np
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt

filename = 'datasets/articles_data_homeproject.csv'

#read a CSV file with pandas
df = pd.read_csv(filename)

# %%
df.head(50)
# Out:
#     Unnamed: 0                source_id              source_name  \
# 0            0                  reuters                  Reuters
# 1            1          the-irish-times          The Irish Times
# 2            2          the-irish-times          The Irish Times
# 3            3       al-jazeera-english       Al Jazeera English
# 4            4                 bbc-news                 BBC News
# 5            5                 abc-news                 ABC News
# 6            6                  reuters                  Reuters
# 7            7                  reuters                  Reuters
# 8            8                 bbc-news                 BBC News
# 9            9          the-irish-times          The Irish Times
# 10          10       al-jazeera-english       Al Jazeera English
# 11          11       the-new-york-times       The New York Times
# 12          12                      cnn                      CNN
# ...

# %%
source_name = df.groupby("source_name")
source_name.describe().head()
# Out:
#                    Unnamed: 0                                            \
#                         count         mean          std    min      25%
# source_name
# 460.0                     1.0   750.000000          NaN  750.0   750.00
# ABC News               1139.0  5280.007024  2988.305705    5.0  2785.50
# Al Jazeera English      499.0  5409.611222  3008.228437    3.0  2899.00
# BBC News               1242.0  5244.165862  2952.638996    4.0  2730.75
# Business Insider       1048.0  5429.023855  3112.609350   21.0  2565.50
#
#                                              top_article            ...  \
#                        50%      75%      max       count      mean  ...
# source_name                                                         ...
# 460.0                750.0   750.00    750.0         0.0       NaN  ...
# ABC News            5374.0  7788.50  10432.0      1139.0  0.115891  ...
# Al Jazeera English  5508.0  8104.00  10353.0       499.0  0.078156  ...
# ...

# %%
author_name = df.groupby("author")
author_name.describe()
# Out:
#                                                    Unnamed: 0                \
#                                                         count          mean
# author
# 151.0                                                     1.0    750.000000
# <a target='_blank' href='https://www.businessin...        1.0   5707.000000
# A.J. Baime                                                1.0    680.000000
# A.O. Scott                                                4.0   3926.750000
# ABC NEWS                                                  1.0   2458.000000
# ...                                                       ...           ...
# wsj                                                       2.0   5230.500000
# zlarock@businessinsider.com (Zoë LaRock), Zoë L...        3.0   9150.666667
# Áilín Quinlan                                             1.0  10208.000000
# Áine Cain                                                 9.0   4046.111111
# ...

# %%
df['author'].value_counts().head(15)
# Out:
# The Associated Press                975
# Reuters Editorial                   685
# CBS News                            637
# https://www.facebook.com/bbcnews    533
# Al Jazeera                          312
# The Irish Times                     255
# BBC News                            201
# CBS/AP                               69
# Dan Cancian                          45
# AP                                   35
# Lisa Respers France, CNN             30
# Brendan Cole                         29
# Ewan Palmer                          27
# Thomson Reuters                      25
# David Brennan                        24
# Name: author, dtype: int64

# %%
df['source_name'].value_counts().head(15)
# Out:
# Reuters                    1252
# BBC News                   1242
# The Irish Times            1232
# ABC News                   1139
# CNN                        1132
# Business Insider           1048
# The New York Times          986
# CBS News                    952
# Newsweek                    539
# Al Jazeera English          499
# The Wall Street Journal     333
# ESPN                         82
# 460.0                         1
# Name: source_name, dtype: int64
